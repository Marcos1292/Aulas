# %%
n= (3 /4)
print (n)
print(type(n))
print(int(n))
# Out:
# 0.75
# <class 'float'>
# 0

# %%
Lista_exemplo_01=[1,2,3,4,5,6,7,8]

# %% [markdown]
# # lista : pode se alterar o que esta dentro []

# %%
lista_exemplo_02=['nomes', 'sobrenome']

# %%
print(Lista_exemplo_01[6])
# Out:
# 7

# %% [markdown]
# # tupla : Nao pode mudar o valor que esta dentro ()

# %%
tupla_exemplo= (1,2,3,4,5,6)

# %% [markdown]
# # Dicionários : atribui valores aos nomes {}

# %%
Dicionario = {
    'index' : 1,
    'a' : 2,
}
print(Dicionario)
# Out:
# {'index': 1, 'a': 2}

# %% [markdown]
# # Nomear com listas

# %%
Lista_carros = ['VW', 'Audi', 'Tesla']
marca_carros01,marca_carros02,marca_carros03, = Lista_carros
print(marca_carros01,marca_carros02,marca_carros03)
# Out:
# VW Audi Tesla

# %%
nome = 'ademir'
idade = str(29)  #So vai somar se eu converter 29 para str, pois nao é possivel somar 2 tipo diferentes
nome_completo = nome + ' ' + idade + ' ' + 'Anos'
print(nome_completo)
# Out:
# ademir 29 Anos

# %% [markdown]
# # Comando ROUND -  aarendondamento

# %%
valor_exemplo = 12.02000202
print(valor_exemplo)
# Out:
# 12.02000202

# %%
round(valor_exemplo, 2)  # (variavel, a quantidade de casas que queremos)
# Out:
# 12.02

# %% [markdown]
# # Comando LEN- indica a quantidade d elementos dentro da lista

# %%
lista= [1,2,3,4,5,6,7,8]
dicionaario = {
    'nome' : 'odemir',
    'idade' : 29
}
tupla = (1,2,3)

# %%
len (dicionaario)
# Out:
# 2

# %% [markdown]
# # fatiamento de str

# %%
minha_string = 'qualquer coisa para aprender'

print(type(minha_string))
print(len(minha_string))
# Out:
# <class 'str'>
# 28

# %%
minha_string[0] #seleciona uma posição específica
minha_string[0:10] #seleciona um periodo
# Out:
# 'qualquer c'

# %%
cpf= 'cpf = 248911292'
cpf[-9:]  #exibe apenas as 9 ultimas letras
# Out:
# '248911292'

# %% [markdown]
# # manipulação de str

# %%
string = 'ola mundao '
print(string)
# Out:
# ola mundao

# %%
string.replace('mundao', 'mundo') #substituir
# Out:
# 'ola mundo '

# %%
int(cpf.replace('cpf = ','')) #tira o cpf e transforma em uym valor numnerico
# Out:
# 248911292

# %%
string.startswith('ola') #verificar de inha string começ acom 'xxx'
# Out:
# True

# %%
string.endswith('!') #verificar de minha string termina acom 'xxx'
# Out:
# False

# %%
string.count('m') #contar quanto 'm' aparece na str
# Out:
# 1

# %%
nome = 'marcos'

# %%
nome.capitalize() #deixar o primero bvalor em maiusculo
nome.upper() #transformar tudo em maiusculo
# Out:
# 'MARCOS'

# %%
string_cpf = '123456789'
string_cpf.isdigit() #verificar de existe um valor numero numérico (se tiver alguma letra retorna false
# Out:
# True

# %%
frase= 'hoje o dia esta calor'
frase.find('dia') #encontrar uma frase ( começa a a partir da 7° posição) ,  se nao existir ele retorna -1
# Out:
# 7

# %%
palavra = 'rua augusta 150, centro, sp'
palavra.split(',') # esse comando vai quebrar a frase no lugar que queremos
# Out:
# ['rua augusta 150', ' centro', ' sp']

# %% [markdown]
# # imput

# %%
input('alguma mensagem')
# Out:
# alguma mensagem oç;oç;
# 'oç;oç;'

# %%
nome = input('qual seu nome?')
idade = input('qual sua idade')

print('seu nome é: ',nome)
print('sua idade é: ',idade)

# %%
lista = [1,2,3,4,5,6,7,8,9]

2 not in lista

# %%
2 in lista

# %% [markdown]
# # identidade

# %%
string01 = 'ola mundao'
string02 = 'ola mundo'
type(string01) is type(string02)  # equivalente a '=='
# Out:
# True

# %% [markdown]
# # Operadores de associação

# %%
marcos = ['magalu','center','mercado']

'via'  in  marcos # verifica se o 'via' esta ndentro da lista, para que nao, usa-se 'not in'
# Out:
# False

# %% [markdown]
# # Mnaipulkçao de listas

# %%
lista_vazia = []
    print(lista_vazia)
# Out:
#   Cell In[31], line 2
#     print(lista_vazia)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# append -  Adiciona um termo na lista

# %%
lista_vazia.append(1) 
lista_vazia.append(2)
lista_vazia.append(3)
print(lista_vazia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 lista_vazia.append(1)
#       2 lista_vazia.append(2)
#       3 lista_vazia.append(3)
#
# NameError: name 'lista_vazia' is not defined

# %%
lista_vazia.clear() #zera a lista 
print(lista_vazia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 lista_vazia.clear() #zera a lista
#       2 print(lista_vazia)
#
# NameError: name 'lista_vazia' is not defined

# %%
lista1= [ 1,2,3,4]
lista2 = [6,7,8]
lista1.extend(lista2) #vai adicionar a lista 2 na liosta 1

# %%
print(lista1)
# Out:
# [1, 2, 3, 4, 6, 7, 8]

# %%
lista1.remove(2) #remove um elemento
print(lista1)
# Out:
# [1, 3, 4, 6, 7, 8]

# %% [markdown]
# # Pacote DATETIME

# %%
import datetime
dia_hoje = datetime.datetime.today()
data = datetime.datetime.today().date()
print(dia_hoje)
# Out:
# 2024-08-20 16:45:34.750438

# %%
ano= dia_hoje.year
mes= dia_hoje.month
dia= dia_hoje.day

print(ano,mes,dia)
# Out:
# 2024 8 20

# %%
data_antiga = datetime.date(2022,1,1)
dias= data - data_antiga
print(dias)
# Out:
# 962 days, 0:00:00

# %%
data + datetime.timedelta(days=30) # soma 30 dias a apartir da data que vboce definir
# Out:
# datetime.date(2024, 9, 19)

# %% [markdown]
# # Pacote TIME

# %%
import time
time_texto='13 june, 2022'
time.strptime(time_texto, '%d %B, %Y')  #estrair os dadois de uma lista em str
# Out:
# time.struct_time(tm_year=2022, tm_mon=6, tm_mday=13, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=164, tm_isdst=-1)

# %% [markdown]
# # Pacote MATH

# %%
import math

x= 4.2
math.ceil(x) #arredonda para cima
# Out:
# 5

# %%
math.floor(x) #arredonda para baixo
# Out:
# 4

# %% [markdown]
# # Pacote Randow

# %%
import random
random.randint(0,10)  #gerar valores aleatorio entre um periodo
# Out:
# 8

# %% [markdown]
# # pacote statistics

# %%
import statistics
lista = [1,2,3,4,5,677,54,23,43,43,56]
statistics.mean(lista)  #calcula a MEDIA da lista
# Out:
# 82.81818181818181

# %%
statistics.median(lista)  #calcula a MEDIAANA da lista
# Out:
# 23

# %%
statistics.mode(lista)  #calcula a MODa da lista (valor que mais aparece)
# Out:
# 43

# %%
idade = int(input('Qual a sua idade?'))

if idade >=18:
    print('voce é maior de idade')
elif idade >=15 and idade <=17:
    print('apenas com autorização')
else:
    print('voce é menor de idade')
# Out:
# Qual a sua idade? l;/~
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 idade = int(input('Qual a sua idade?'))
#       3 if idade >=18:
#       4     print('voce é maior de idade')
#
# ValueError: invalid literal for int() with base 10: 'l;/~'

# %% [markdown]
# # for in Range

# %%
for qualquercoisa in range(3,11,2):  #Cria um looping q deveser executado de 3 a 11, pulando de 2 a 2
    
    print(qualquercoisa)

# %%
lista=['brasil, argentina, chile'] 

for qualquercoisacoisa in lista:
    print(qualquercoisacoisa)

# %%
lista=['brasil', 'argentina', 'chile'] #Vai fazer o loop de acordo com o tamanho da lista
for Loop in range (len(lista)):
    print(Loop)

# %%
for Loop in range (len(lista)):
    print(lista[Loop]) #vai ler a lista e plotyar os dados

# %% [markdown]
# for index, Loop in enumerate(lista):
#     print(index, Loop) #vai ler a lista e plotyar os dados e enumeraer

# %%
x=0
for Loop in lista:
    x = x+1
    print(x,Loop)

# %%
lista=[]

for Loop in range(0,110):
    lista.append(Loop)
print(lista)

# %% [markdown]
# # while

# %%
import random
parar = 0
aleatorio = []
while parar<=100:
    aleatorio.append(random.randint(1,9))
    print(aleatorio)
    parar +=1

# %%
while True :

    eu= random.randint(0,3)
    voces= random.randint(2,10)

    print('eu tirei o velor ', eu)
    print('voce tiraream o velor ', voces)

    if eu > voces:
        print('ganhei')
        break              # Vai interromper o o loop quando essa condição for feita
    print('\n')

# %%
for loop in range(0,11):  # Pode ser usado, quando dar um certo valor, ele é ignorado no loop
    if loop == 5:
        continue
    print (loop)

# %% [markdown]
# # Try e except

# %%
try: #vai tentar executar essa parte
    0/0
    print('deu certo') #se deu certo retorna isso
except: # se nao deu certo ele vaiu para esse
    print('nao deu certo')

# %% [markdown]
# # BiBLIOTECAS

# %%
import os
import pandas as pd
import polars as pl
import matplotlib.pyplot as pl

# %%
df = pd.read_csv("C:/Users/marcos perrude/Downloads/poluicao/ENS5173_202401/Aulas/dados_enem_2021_BA/dados_enem_2021_BA.csv")

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210051128744    2021                4       F                1
# 1  210054173438    2021                5       F                1
# 2  210052118573    2021                3       F                1
# 3  210052350230    2021               10       F                1
# 4  210053156861    2021                9       M                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            3                 1                2                0          2
# 1            2                 1                2                0          2
# 2            3                 1                2                0          2
# 3            2                 1                1                8          1
# 4            2                 1                1                5          1
#
#    ...                                 TX_GABARITO_CH  \
# ...

# %%
df.tail()
# Out:
#         NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 266189  210051432069    2021               12       M                1
# 266190  210051106175    2021               14       M                2
# 266191  210051995005    2021               11       M                0
# 266192  210053234415    2021               12       M                2
# 266193  210054027870    2021                5       F                1
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 266189            3                 1                1                0
# 266190            2                 1                1                0
# 266191            2                 1                1               12
# 266192            2                 1                1               15
# 266193            2                 1                1                2
#
#         TP_ESCOLA  ...  TX_GABARITO_CH  TX_GABARITO_LC  TX_GABARITO_MT  \
# ...

# %%
df.shape
# Out:
# (266194, 51)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266194 entries, 0 to 266193
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   NU_INSCRICAO            266194 non-null  int64
#  1   NU_ANO                  266194 non-null  int64
#  2   TP_FAIXA_ETARIA         266194 non-null  int64
#  3   TP_SEXO                 266194 non-null  object
#  4   TP_ESTADO_CIVIL         266194 non-null  int64
#  5   TP_COR_RACA             266194 non-null  int64
#  6   TP_NACIONALIDADE        266194 non-null  int64
#  7   TP_ST_CONCLUSAO         266194 non-null  int64
#  8   TP_ANO_CONCLUIU         266194 non-null  int64
#  9   TP_ESCOLA               266194 non-null  int64
#  10  TP_ENSINO               84388 non-null   float64
#  11  IN_TREINEIRO            266194 non-null  int64
#  12  CO_MUNICIPIO_ESC        47820 non-null   float64
#  13  NO_MUNICIPIO_ESC        47820 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
#        'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA',
#        'SG_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT',
#        'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC',
#        'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN', 'TX_GABARITO_CH',
#        'TX_GABARITO_LC', 'TX_GABARITO_MT', 'TP_STATUS_REDACAO',
#        'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4',
#        'NU_NOTA_COMP5', 'NU_NOTA_REDACAO'],
# ...

# %%
df.isna()   #Verificando se possui dados faltantes (False é que possui)
# Out:
#         NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA  TP_SEXO  TP_ESTADO_CIVIL  \
# 0              False   False            False    False            False
# 1              False   False            False    False            False
# 2              False   False            False    False            False
# 3              False   False            False    False            False
# 4              False   False            False    False            False
# ...              ...     ...              ...      ...              ...
# 266189         False   False            False    False            False
# 266190         False   False            False    False            False
# 266191         False   False            False    False            False
# 266192         False   False            False    False            False
# 266193         False   False            False    False            False
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
df.isna().sum()
# Out:
# NU_INSCRICAO                   0
# NU_ANO                         0
# TP_FAIXA_ETARIA                0
# TP_SEXO                        0
# TP_ESTADO_CIVIL                0
# TP_COR_RACA                    0
# TP_NACIONALIDADE               0
# TP_ST_CONCLUSAO                0
# TP_ANO_CONCLUIU                0
# TP_ESCOLA                      0
# TP_ENSINO                 181806
# IN_TREINEIRO                   0
# CO_MUNICIPIO_ESC          218374
# NO_MUNICIPIO_ESC          218374
# CO_UF_ESC                 218374
# SG_UF_ESC                 218374
# TP_DEPENDENCIA_ADM_ESC    218374
# TP_LOCALIZACAO_ESC        218374
# TP_SIT_FUNC_ESC           218374
# CO_MUNICIPIO_PROVA             0
# NO_MUNICIPIO_PROVA             0
# CO_UF_PROVA                    0
# SG_UF_PROVA                    0
# TP_PRESENCA_CN                 0
# TP_PRESENCA_CH                 0
# TP_PRESENCA_LC                 0
# TP_PRESENCA_MT                 0
# CO_PROVA_CN                90838
# ...

# %%
df.describe().transpose()
# Out:
#                            count          mean            std           min  \
# NU_INSCRICAO            266194.0  2.100527e+11  981957.687860  2.100510e+11
# NU_ANO                  266194.0  2.021000e+03       0.000000  2.021000e+03
# TP_FAIXA_ETARIA         266194.0  5.710166e+00       3.878161  1.000000e+00
# TP_ESTADO_CIVIL         266194.0  1.048991e+00       0.411030  0.000000e+00
# TP_COR_RACA             266194.0  2.301832e+00       0.907761  0.000000e+00
# TP_NACIONALIDADE        266194.0  1.029787e+00       0.194507  0.000000e+00
# TP_ST_CONCLUSAO         266194.0  1.595810e+00       0.719902  1.000000e+00
# TP_ANO_CONCLUIU         266194.0  2.846845e+00       4.468500  0.000000e+00
# TP_ESCOLA               266194.0  1.379663e+00       0.570947  1.000000e+00
# TP_ENSINO                84388.0  1.013272e+00       0.114438  1.000000e+00
# IN_TREINEIRO            266194.0  1.226587e-01       0.328046  0.000000e+00
# ...

# %%
df.TP_ESCOLA # Sleciona a coluna
# Out:
# 0         2
# 1         2
# 2         2
# 3         1
# 4         1
#          ..
# 266189    1
# 266190    1
# 266191    1
# 266192    1
# 266193    1
# Name: TP_ESCOLA, Length: 266194, dtype: int64

# %%
df.TP_ESCOLA.value_counts() #Distribuição de frequencia
# Out:
# TP_ESCOLA
# 1    177170
# 2     76984
# 3     12040
# Name: count, dtype: int64

# %%
 df[['TP_SEXO', 'TP_ESCOLA']]  #sELECIONA MUITIPLAS COLUNAS
# Out:
#        TP_SEXO  TP_ESCOLA
# 0            F          2
# 1            F          2
# 2            F          2
# 3            F          1
# 4            M          1
# ...        ...        ...
# 266189       M          1
# 266190       M          1
# 266191       M          1
# 266192       M          1
# 266193       F          1
#
# [266194 rows x 2 columns]

# %%
df.iloc[:,0]  #seleciona a coluna pela posição ( ':' todas linhas, '0' da coluna n posição 0)
# Out:
# 0         210051128744
# 1         210054173438
# 2         210052118573
# 3         210052350230
# 4         210053156861
#               ...
# 266189    210051432069
# 266190    210051106175
# 266191    210051995005
# 266192    210053234415
# 266193    210054027870
# Name: NU_INSCRICAO, Length: 266194, dtype: int64

# %%
df.iloc[0:5,0]  #Dados das 5 primeiras linhas da coluna 0
# Out:
# 0    210051128744
# 1    210054173438
# 2    210052118573
# 3    210052350230
# 4    210053156861
# Name: NU_INSCRICAO, dtype: int64

# %%
df.select_dtypes(include = object)  #Selecionar as colunas que sao objeto
# Out:
#        TP_SEXO NO_MUNICIPIO_ESC SG_UF_ESC NO_MUNICIPIO_PROVA SG_UF_PROVA  \
# 0            F              NaN       NaN        Ruy Barbosa          BA
# 1            F         Salvador        BA           Salvador          BA
# 2            F              NaN       NaN          Barreiras          BA
# 3            F              NaN       NaN      Santo Estêvão          BA
# 4            M              NaN       NaN   Feira de Santana          BA
# ...        ...              ...       ...                ...         ...
# 266189       M              NaN       NaN         Alagoinhas          BA
# 266190       M              NaN       NaN           Juazeiro          BA
# 266191       M              NaN       NaN           Salvador          BA
# 266192       M              NaN       NaN           Salvador          BA
# 266193       F              NaN       NaN           Salvador          BA
#
#                                       TX_RESPOSTAS_CN  \
# ...

# %%
 cat_cols = df.select_dtypes(include = object). columns.tolist() #Seleciona as colunas com o typo "objeto" e retorna uma lista com elas
print (cat_cols)
# Out:
# ['TP_SEXO', 'NO_MUNICIPIO_ESC', 'SG_UF_ESC', 'NO_MUNICIPIO_PROVA', 'SG_UF_PROVA', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC', 'TX_GABARITO_MT']

# %%
cat_num = df.select_dtypes(include = [int, float]). columns.tolist() #Seleciona as colunas com o typo "int e float" e retorna uma lista com elas
print (cat_num)
# Out:
# ['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'CO_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'TP_LINGUA', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_REDACAO']

# %% [markdown]
# # existe diferença na nota entre escola publica e privada??

# %%
df.query('TP_ESCOLA == 2').NU_NOTA_MT.mean()  #pegou os alunos de escola publica(tipo 2), fe\z a media da nota de matematica (coluna NU_NOTA_MT)
# Out:
# 487.37504991538157

# %%
df.query('TP_ESCOLA == 3').NU_NOTA_MT.mean() #pegou os alunos de escola privada(tipo 3), fe\z a media da nota de matematica (coluna NU_NOTA_MT)
# Out:
# 579.8338996340826

# %%
import numpy as np
df.query('TP_ESCOLA == 3').NU_NOTA_MT.agg([np.mean, np.median])
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\3018918382.py:2: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.query('TP_ESCOLA == 3').NU_NOTA_MT.agg([np.mean, np.median])
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\3018918382.py:2: FutureWarning: The provided callable <function median at 0x000002212523EDE0> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.query('TP_ESCOLA == 3').NU_NOTA_MT.agg([np.mean, np.median])
# mean      579.8339
# median    581.6000
# Name: NU_NOTA_MT, dtype: float64

# %%
df.query('TP_ESCOLA == 2').NU_NOTA_MT.agg([np.mean, np.median])
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\571288513.py:1: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.query('TP_ESCOLA == 2').NU_NOTA_MT.agg([np.mean, np.median])
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\571288513.py:1: FutureWarning: The provided callable <function median at 0x000002212523EDE0> is currently using Series.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.query('TP_ESCOLA == 2').NU_NOTA_MT.agg([np.mean, np.median])
# mean      487.37505
# median    468.90000
# Name: NU_NOTA_MT, dtype: float64

# %%
df.query('TP_SEXO == "M"').sample(5) # Retorna apenas alunos do sexo Masculino das
# Out:
#         NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 181553  210051370929    2021                3       M                1
# 155787  210054149876    2021                5       M                1
# 253047  210053590651    2021               13       M                1
# 187840  210051306285    2021                3       M                1
# 96984   210051548672    2021                3       M                1
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 181553            1                 1                1                1
# 155787            3                 1                1                2
# 253047            1                 2                1               15
# 187840            1                 1                2                0
# 96984             0                 1                2                0
#
#         TP_ESCOLA  ...                                 TX_GABARITO_CH  \
# ...

# %%
df.query('(TP_SEXO == "M") and (IN_TREINEIRO == 1)')
# Out:
#         NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 69      210053707047    2021                1       M                1
# 113     210051127853    2021                1       M                1
# 151     210053634740    2021                5       M                1
# 155     210052073811    2021                1       M                1
# 204     210053593141    2021                2       M                1
# ...              ...     ...              ...     ...              ...
# 265284  210051161032    2021                1       M                1
# 265325  210051362311    2021                2       M                1
# 265359  210051833040    2021                2       M                1
# 265994  210054130477    2021                4       M                1
# 266084  210053795196    2021                4       M                1
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
mask = df.TP_SEXO =='M' #Mascara boleana (Retorna de uma condiçõ é retornada)

# %%
print(mask)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 266189     True
# 266190     True
# 266191     True
# 266192     True
# 266193    False
# Name: TP_SEXO, Length: 266194, dtype: bool

# %%
# Uma forma de oganizar é uitilizar variaveis 
condicao1 = df.TP_SEXO =='M'
condicao2 = df.IN_TREINEIRO == 1
df.loc[(condicao1) and (condicao2)].sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8120\1873143987.py in ?()
#       1 # Uma forma de oganizar é uitilizar variaveis
#       2 condicao1 = df.TP_SEXO =='M'
#       3 condicao2 = df.IN_TREINEIRO == 1
# ----> 4 df.loc[(condicao1) and (condicao2)].sample(5)
#
# ~\Downloads\poluicao\ENS5173_202401\venv\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1574     @final
#    1575     def __nonzero__(self) -> NoReturn:
# -> 1576         raise ValueError(
#    1577             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1578             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1579         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df.NO_MUNICIPIO_PROVA.isin(['Itabuna' , 'Salvador'])]  # Seleciona os individuos que residem em itabuna e slavador (isin cir auma lista com os nomes das variaveis)

# %%
df[-(df.NO_MUNICIPIO_PROVA.isin(['Salvador']))] #Pega os launos que nao residen no municio de Salvador

# %%
df.columns[df.columns.str.contains('NOTA') & (~df.columns.str.contains('COMP'))].tolist()
# Out:
# ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']

# %%
idcandidato = ['NU_CANDIDATO']

# %%
import matplotlib.pyplot as plt
df.TP_ESCOLA.value_counts().plot(kind= 'bar')
plt.title('Proporção de alunos de cada tipo de escola')
# Out:
# Text(0.5, 1.0, 'Proporção de alunos de cada tipo de escola')

# %%
df.TP_SEXO.value_counts().plot(kind ='bar' ,color ='Yellow')
plt.title('Proporção de genero')
plt.xlabel('Sexo')
plt.ylabel('Quanttidade')
plt.show()

# %%
(df.NO_MUNICIPIO_PROVA
 .value_counts()
 .reset_index() #Trannsforma em Dataframe
 .rename(columns = { 'NO_MUNICIPIO_PROVA' : 'Municipio' , 'count' : 'Quantidade'}) # Renomear os nomes das colunas
 .nlargest(n =15 ,columns = 'Quantidade')
 .set_index('Municipio')
 .plot(
     kind = 'barh',
     color = 'black',
     legend = False,
     xlabel = 'Quantidade',
     title = 'Municipios com maior quantidade d einscritos'
     )
    
)
# Out:
# <Axes: title={'center': 'Municipios com maior quantidade d einscritos'}, xlabel='Quantidade', ylabel='Municipio'>

# %%
(
    df.TP_ESCOLA.map({1:'Nao respondeu', 2:'Publica', 3:'Privada'})
    .value_counts()
    .plot(kind = 'pie',
        legend = False,
        autopct = '%.2f', #Exibir a porcentagem com 2 casas
        ylabel = ""
         )
        
);

# %%
df.plot(kind = 'scatter' , x = 'NU_NOTA_MT', y = 'NU_NOTA_CN' )
# Out:
# <Axes: xlabel='NU_NOTA_MT', ylabel='NU_NOTA_CN'>

# %%
df.NU_NOTA_MT.plot(kind ='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.NU_NOTA_MT.plot(kind ='box')
# Out:
# <Axes: >

# %%
df.NU_NOTA_MT.plot(kind ='kde')# AnLISA A DENSIDADE DE PROBABILIDADE DE UMA NOTA
# Out:
# <Axes: ylabel='Density'>

# %%
(df
 .groupby (by = ['NO_MUNICIPIO_PROVA'])
 .agg({'NU_NOTA_MT' : np.mean})
 .reset_index()
 .rename(columns = {'NU_NOTA_MT' :'Nota' , 'NO_MUNICIPIO_PROVA': 'Municipio'})
 .nlargest(n = 10, columns = 'Nota')
 .plot (
     x ='Municipio',
     y = 'Nota',
     figsize = (15,10),
     color = 'k',
     ylabel = 'media em matematica',
     xlabel = 'nota media',
     ylim = (520,545)
 )
)

# %% [markdown]
# # Ordenação

# %%
df_test = df_test.set_index(['NO_MUNICIPIO_PROVA','TO_SEXO'])

# %%
df.head().transpose()
# Out:
#                                                                         0  \
# NU_INSCRICAO                                                 210051128744
# NU_ANO                                                               2021
# TP_FAIXA_ETARIA                                                         4
# TP_SEXO                                                                 F
# TP_ESTADO_CIVIL                                                         1
# TP_COR_RACA                                                             3
# TP_NACIONALIDADE                                                        1
# TP_ST_CONCLUSAO                                                         2
# TP_ANO_CONCLUIU                                                         0
# TP_ESCOLA                                                               2
# TP_ENSINO                                                             1.0
# IN_TREINEIRO                                                            0
# ...

# %%
pd.set_option('display.max_columns',100)

# %%
df = pd.read_csv("C:/Users/marcos perrude/Downloads/poluicao/ENS5173_202401/Aulas/dados_enem_2021_BA/dados_enem_2021_BA.csv")

# %%
df.shape
# Out:
# (266194, 51)

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210051128744    2021                4       F                1
# 1  210054173438    2021                5       F                1
# 2  210052118573    2021                3       F                1
# 3  210052350230    2021               10       F                1
# 4  210053156861    2021                9       M                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            3                 1                2                0          2
# 1            2                 1                2                0          2
# 2            3                 1                2                0          2
# 3            2                 1                1                8          1
# 4            2                 1                1                5          1
#
#    TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC  \
# ...

# %% [markdown]
#  Media da nota de matematica por genoro

# %% [markdown]
# # Agregação

# %%
subset_tp_m = df.query('TP_SEXO =="M"')

# %%
subset_tp_f = df.query('TP_SEXO =="F"')

# %%
subset_tp_m.NU_NOTA_MT.max() #Nota max do gernero masculino
# Out:
# 953.1

# %%
subset_tp_f.NU_NOTA_MT.max()
# Out:
# 944.1

# %%
subset_tp_m.NU_NOTA_MT.mean() #Nota media do subset  masculino
# Out:
# 538.500684898471

# %%
subset_tp_f.NU_NOTA_MT.mean()
# Out:
# 499.7702519508294

# %%
subset_tp_m.NU_NOTA_MT.median() #Nota mediana do subset  masculino
# Out:
# 522.0

# %%
subset_tp_f.NU_NOTA_MT.median() #Nota mediana do subset  masculino
# Out:
# 478.2

# %%
provas = df.columns[df.columns.str.contains('NOTA') & (~df.columns.str.contains('COMP'))].tolist()
idCandidato = ['NU_INSCRICAO']

# %%
#Função de agregação
import numpy as np
subset_tp_m[provas].agg([np.min , np.mean, np.median, np.max]).T
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\261910405.py:3: FutureWarning: The provided callable <function min at 0x00000221250F9800> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   subset_tp_m[provas].agg([np.min , np.mean, np.median, np.max]).T
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\261910405.py:3: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   subset_tp_m[provas].agg([np.min , np.mean, np.median, np.max]).T
# ...

# %%
subset_tp_f[provas].agg([np.min , np.mean, np.median, np.max]).T.round(2)  #Cria um subset com diversos parâmetros para ser analisado, '.T' para fazer a transporta e facilitar a visualização. '.round[2]' serve para formatar para 2 casas decimais
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\2741708876.py:1: FutureWarning: The provided callable <function min at 0x00000221250F9800> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   subset_tp_f[provas].agg([np.min , np.mean, np.median, np.max]).T.round(2)  #Cria um subset com diversos parâmetros para ser analisado, '.T' para fazer a transporta e facilitar a visualização. '.round[2]' serve para formatar para 2 casas decimais
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\2741708876.py:1: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# ...

# %%
#Qual foi o aluno que tirou a nota maxima?
df.NU_NOTA_MT.max()
# Out:
# 953.1

# %%
df.NU_NOTA_MT.idxmax() #Retorna o indice(Linha) que comtem a =nota maxima
# Out:
# 55177

# %%
df.iloc[55177, :]
# Out:
# NU_INSCRICAO                                                   210053912306
# NU_ANO                                                                 2021
# TP_FAIXA_ETARIA                                                           2
# TP_SEXO                                                                   M
# TP_ESTADO_CIVIL                                                           1
# TP_COR_RACA                                                               3
# TP_NACIONALIDADE                                                          1
# TP_ST_CONCLUSAO                                                           2
# TP_ANO_CONCLUIU                                                           0
# TP_ESCOLA                                                                 3
# TP_ENSINO                                                               1.0
# IN_TREINEIRO                                                              0
# ...

# %%
#De forma mais direta, identifica a id do aluno que tirou a maior nota em matematica

df.iloc[df.NU_NOTA_MT.idxmax(),]
# Out:
# NU_INSCRICAO                                                   210053912306
# NU_ANO                                                                 2021
# TP_FAIXA_ETARIA                                                           2
# TP_SEXO                                                                   M
# TP_ESTADO_CIVIL                                                           1
# TP_COR_RACA                                                               3
# TP_NACIONALIDADE                                                          1
# TP_ST_CONCLUSAO                                                           2
# TP_ANO_CONCLUIU                                                           0
# TP_ESCOLA                                                                 3
# TP_ENSINO                                                               1.0
# IN_TREINEIRO                                                              0
# ...

# %%
df.iloc[df.NU_NOTA_MT.idxmin(),]
# Out:
# NU_INSCRICAO                                                   210053803513
# NU_ANO                                                                 2021
# TP_FAIXA_ETARIA                                                           3
# TP_SEXO                                                                   M
# TP_ESTADO_CIVIL                                                           1
# TP_COR_RACA                                                               3
# TP_NACIONALIDADE                                                          1
# TP_ST_CONCLUSAO                                                           2
# TP_ANO_CONCLUIU                                                           0
# TP_ESCOLA                                                                 2
# TP_ENSINO                                                               1.0
# IN_TREINEIRO                                                              0
# ...

# %%
df[df.NU_NOTA_REDACAO != 0].NU_NOTA_REDACAO
# Out:
# 0         380.0
# 1           NaN
# 2         460.0
# 3         580.0
# 4         540.0
#           ...
# 266189      NaN
# 266190      NaN
# 266191      NaN
# 266192      NaN
# 266193      NaN
# Name: NU_NOTA_REDACAO, Length: 260386, dtype: float64

# %%
df[df.NU_NOTA_REDACAO.notna()].NU_NOTA_REDACAO
# Out:
# 0         380.0
# 2         460.0
# 3         580.0
# 4         540.0
# 5         700.0
#           ...
# 266164    560.0
# 266168    580.0
# 266174    500.0
# 266184    260.0
# 266188    280.0
# Name: NU_NOTA_REDACAO, Length: 184844, dtype: float64

# %% [markdown]
# Qual a menor nota em redação sem ser 0 ?

# %%
#Algo mais elaborado
mask1 = df.NU_NOTA_REDACAO.notna() #fILTRA PARA NAO HAVER NOTAS NAO COMPARECIDOS(NAO FEZ ENEM)
mask2 = df.NU_NOTA_REDACAO != 0 #FILTRAR PARA NAO HAVER NOTAS 0
subset = df[(mask1) & (mask2)]

# %%
subset.NU_NOTA_REDACAO.plot(kind ='box')  #Confirmar que nao possui notas 0
subset.NU_NOTA_REDACAO.plot(kind ='hist')  #Confirmar que nao possui notas 0
# Out:
# <Axes: ylabel='Frequency'>

# %%
subset.NU_NOTA_REDACAO.agg([np.min, np.mean, np.median , np.max])  #RESPOSTAS
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\983498081.py:1: FutureWarning: The provided callable <function min at 0x00000221250F9800> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   subset.NU_NOTA_REDACAO.agg([np.min, np.mean, np.median , np.max])  #RESPOSTAS
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\983498081.py:1: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   subset.NU_NOTA_REDACAO.agg([np.min, np.mean, np.median , np.max])  #RESPOSTAS
# ...

# %%
df[provas]
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0            507.6       539.2       494.6       413.3            380.0
# 1              NaN         NaN         NaN         NaN              NaN
# 2            439.6       437.7       455.9       446.2            460.0
# 3            548.1       619.5       676.3       386.6            580.0
# 4            465.2       613.1       522.1       579.6            540.0
# ...            ...         ...         ...         ...              ...
# 266189         NaN         NaN         NaN         NaN              NaN
# 266190         NaN         NaN         NaN         NaN              NaN
# 266191         NaN         NaN         NaN         NaN              NaN
# 266192         NaN         NaN         NaN         NaN              NaN
# 266193         NaN         NaN         NaN         NaN              NaN
#
# [266194 rows x 5 columns]

# %%
df[provas].mean() #Faz as medias das colunas (Media de cada materia (ou df[provas].mean(axis=0)
# Out:
# NU_NOTA_CN         479.939563
# NU_NOTA_CH         506.234466
# NU_NOTA_LC         489.131131
# NU_NOTA_MT         513.507987
# NU_NOTA_REDACAO    606.276969
# dtype: float64

# %%
df[provas].mean(axis =1) #Faz as medias das clinhas  (Media de cada aluno)
# Out:
# 0         466.94
# 1            NaN
# 2         447.88
# 3         562.10
# 4         544.00
#            ...
# 266189       NaN
# 266190       NaN
# 266191       NaN
# 266192       NaN
# 266193       NaN
# Length: 266194, dtype: float64

# %%
df[provas].mean(axis =1).fillna(-1)  #Em missin(informaçoes faltantes) aplixca o valor -1
# Out:
# 0         466.94
# 1          -1.00
# 2         447.88
# 3         562.10
# 4         544.00
#            ...
# 266189     -1.00
# 266190     -1.00
# 266191     -1.00
# 266192     -1.00
# 266193     -1.00
# Length: 266194, dtype: float64

# %%
df_copy =df.copy()
df['MEAN'] = df[provas].mean(axis =1).fillna(-1) #Criou uma coluna 'mean'

# %%
df
# Out:
#         NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0       210051128744    2021                4       F                1
# 1       210054173438    2021                5       F                1
# 2       210052118573    2021                3       F                1
# 3       210052350230    2021               10       F                1
# 4       210053156861    2021                9       M                1
# ...              ...     ...              ...     ...              ...
# 266189  210051432069    2021               12       M                1
# 266190  210051106175    2021               14       M                2
# 266191  210051995005    2021               11       M                0
# 266192  210053234415    2021               12       M                2
# 266193  210054027870    2021                5       F                1
#
#         TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %% [markdown]
# # Agrupamento

# %% [markdown]
# * qual a proporção entre os generos?

# %%
df.TP_SEXO.value_counts()#Vai contar a quantidade de cada valor
# Out:
# TP_SEXO
# F    171997
# M     94197
# Name: count, dtype: int64

# %%
df.groupby(by = ['TP_SEXO'])['NU_INSCRICAO'].count()  #PRIMEIRA É A COLUNA QUE QUERO AGRUPAR, E A SEGUNDA SAO AS COLUNAS QUE QUERO APLICAR A CODIÇÃO
# Out:
# TP_SEXO
# F    171997
# M     94197
# Name: NU_INSCRICAO, dtype: int64

# %%
df.groupby(by = ['TP_SEXO','TP_ESCOLA'])['NU_INSCRICAO'].count()
# Out:
# TP_SEXO  TP_ESCOLA
# F        1            114715
#          2             50561
#          3              6721
# M        1             62455
#          2             26423
#          3              5319
# Name: NU_INSCRICAO, dtype: int64

# %% [markdown]
# * Qual a distribuição de frequencia dos alunos por tipo de escola?

# %%
df.groupby(by = ['TP_ESCOLA'])['NU_INSCRICAO'].count().sort_values() #sort_values ordena pela quantidade
# Out:
# TP_ESCOLA
# 3     12040
# 2     76984
# 1    177170
# Name: NU_INSCRICAO, dtype: int64

# %% [markdown]
# * Qual o desempenho em matematica por tipo de escola

# %%
df.groupby(by = ['TP_ESCOLA'])['NU_NOTA_MT'].mean()
# Out:
# TP_ESCOLA
# 1    519.016313
# 2    487.375050
# 3    579.833900
# Name: NU_NOTA_MT, dtype: float64

# %%
df.groupby(by = ['TP_ESCOLA'])[['NU_NOTA_MT','NU_NOTA_CN']].mean()
# Out:
#            NU_NOTA_MT  NU_NOTA_CN
# TP_ESCOLA
# 1          519.016313  485.694886
# 2          487.375050  458.415743
# 3          579.833900  522.752945

# %%
df.groupby(by = ['TP_ESCOLA'])[['NU_NOTA_MT','NU_NOTA_CN']].agg([np.min , np.median, np.std, np.max]).T
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\2042956543.py:1: FutureWarning: The provided callable <function min at 0x00000221250F9800> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(by = ['TP_ESCOLA'])[['NU_NOTA_MT','NU_NOTA_CN']].agg([np.min , np.median, np.std, np.max]).T
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\2042956543.py:1: FutureWarning: The provided callable <function median at 0x000002212523EDE0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby(by = ['TP_ESCOLA'])[['NU_NOTA_MT','NU_NOTA_CN']].agg([np.min , np.median, np.std, np.max]).T
# ...

# %%
#++++++ ORAGANIZADO
(
    df.groupby(by = ['TP_ESCOLA'])[['NU_NOTA_MT','NU_NOTA_CN']]
    .agg([np.min , np.median, np.std, np.max])
    .T
)
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\1992978840.py:4: FutureWarning: The provided callable <function min at 0x00000221250F9800> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   .agg([np.min , np.median, np.std, np.max])
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\1992978840.py:4: FutureWarning: The provided callable <function median at 0x000002212523EDE0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   .agg([np.min , np.median, np.std, np.max])
# ...

# %%
(
    df.groupby( by = ['TP_ESCOLA']) # Classifica pelo grupo : tp escola
    .agg({ #Analisa esses parametros por cada tp escola
        'NU_NOTA_MT' : [np.mean, np.median],  #diferentes parametros por cada coluna
        'NU_NOTA_CN' : [np.min, np.max]
    }
    )
)
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\1165251563.py:3: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   .agg({ #Analisa esses parametros por cada tp escola
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\1165251563.py:3: FutureWarning: The provided callable <function median at 0x000002212523EDE0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   .agg({ #Analisa esses parametros por cada tp escola
# ...

# %%
df.NO_MUNICIPIO_PROVA
# Out:
# 0              Ruy Barbosa
# 1                 Salvador
# 2                Barreiras
# 3            Santo Estêvão
# 4         Feira de Santana
#                 ...
# 266189          Alagoinhas
# 266190            Juazeiro
# 266191            Salvador
# 266192            Salvador
# 266193            Salvador
# Name: NO_MUNICIPIO_PROVA, Length: 266194, dtype: object

# %%
(
    df
    .groupby(by = ['NO_MUNICIPIO_PROVA'])['NU_NOTA_MT']
    .agg([np.min , np.mean, np.median, np.max])
    .reset_index(drop = False)  #Retirar o NO_MUNICIOI_PROVA como index
    .rename(columns = { 'NO_MUNICIPIO_PROVA' : 'Município',
                       'min' : 'Mínimo',
                       'mean' : 'Média',
                       'median' : 'Mediana',
                       'max' : 'Máximo'
                      })
    .sort_values(by = ['Máximo','Média', 'Mediana'], ascending = False)  # Ordenador pro maior - menor

)
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\672800202.py:4: FutureWarning: The provided callable <function min at 0x00000221250F9800> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   .agg([np.min , np.mean, np.median, np.max])
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\672800202.py:4: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   .agg([np.min , np.mean, np.median, np.max])
# ...

# %%
# Deve trazer o codigo do municípios

(
    df                                       #Chama o codigo
    .query('NU_NOTA_MT != 0') #pARA PEGAR NOTAS DIFERENTE DE 0
    .groupby(by = ['NO_MUNICIPIO_PROVA', 'CO_MUNICIPIO_PROVA'])['NU_NOTA_MT']
    .agg([np.min , np.mean, np.median, np.max])
    .reset_index(drop = False)  #Retirar o NO_MUNICIOI_PROVA como index
    .rename(columns = { 'NO_MUNICIPIO_PROVA' : 'Município',
                       'CO_MUNICIPIO_PROVA' : 'Código_IBGE' ,
                       'min' : 'Mínimo',
                       'mean' : 'Média',
                       'median' : 'Mediana',
                       'max' : 'Máximo'
                      })
    .sort_values(by = ['Máximo','Média', 'Mediana'], ascending = False)  # Ordenador pro maior - menor

)
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\3281935841.py:7: FutureWarning: The provided callable <function min at 0x00000221250F9800> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   .agg([np.min , np.mean, np.median, np.max])
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\3281935841.py:7: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   .agg([np.min , np.mean, np.median, np.max])
# ...

# %%
# Para organizar o indice
df_visao_municipio = (
(
    df                                       #Chama o codigo
    .query('NU_NOTA_MT != 0') #pARA PEGAR NOTAS DIFERENTE DE 0
    .groupby(by = ['NO_MUNICIPIO_PROVA', 'CO_MUNICIPIO_PROVA'])['NU_NOTA_MT']
    .agg([np.min , np.mean, np.median, np.max])
    .reset_index(drop = False)  #Retirar o NO_MUNICIOI_PROVA como index
    .rename(columns = { 'NO_MUNICIPIO_PROVA' : 'Município',
                       'CO_MUNICIPIO_PROVA' : 'COD_IBGE' ,
                       'min' : 'Mínimo_MT',
                       'mean' : 'Média_MT',
                       'median' : 'Mediana_MT',
                       'max' : 'Máximo_MT'
                      })
    .sort_values(by = ['Máximo_MT','Média_MT', 'Mediana_MT'], ascending = False)  # Ordenador pro maior - menor
    .reset_index(drop = True)  #Organizar o indece
)
)
# Out:
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\2898658495.py:7: FutureWarning: The provided callable <function min at 0x00000221250F9800> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   .agg([np.min , np.mean, np.median, np.max])
# C:\Users\marcos perrude\AppData\Local\Temp\ipykernel_8120\2898658495.py:7: FutureWarning: The provided callable <function mean at 0x00000221250FA0C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   .agg([np.min , np.mean, np.median, np.max])
# ...

# %%
df_visao_municipio
# Out:
#                   Município  COD_IBGE  Mínimo_MT    Média_MT  Mediana_MT  \
# 0      Vitória da Conquista   2933307      315.5  536.491289      517.30
# 1                  Salvador   2927408      315.3  534.623544      515.60
# 2                 Barreiras   2903201      318.8  517.589528      496.80
# 3          Feira de Santana   2910800      316.0  525.103365      502.90
# 4                  Serrinha   2930501      346.8  501.138564      479.85
# ..                      ...       ...        ...         ...         ...
# 157               Cansanção   2906808      360.9  475.027413      459.20
# 158  Oliveira dos Brejinhos   2923209      380.6  505.673239      488.10
# 159                Sento Sé   2930204      367.8  476.352846      462.30
# 160               Umburanas   2932457      357.6  464.582090      453.50
# 161               Caravelas   2906907      352.9  490.168085      480.50
#
#      Máximo_MT
# 0        953.1
# 1        953.1
# 2        948.8
# 3        948.5
# ...

# %%
df_quantidade_inscritos = (
(
    df.groupby(by = ['NO_MUNICIPIO_PROVA', 'CO_MUNICIPIO_PROVA'], as_index = False)['NU_INSCRICAO']
    .count()
    .rename (columns = {'NO_MUNICIPIO_PROVA' :'Município',
                        'CO_MUNICIPIO_PROVA' : 'COD_IBGE',
                        'NU_INSCRICAO' : 'Quantidade_Inscritos'
                       })
    .sort_values(by = ['Quantidade_Inscritos'], ascending = False)
    .reset_index(drop = True)  #Organizar o indece
)
)

# %%
#Quantidades de inscritos em  porcentgem

total = (df_quantidade_inscritos.Quantidade_Inscritos.sum())

# %%
(df_quantidade_inscritos.Quantidade_Inscritos/ total* 100).round(2)  #Divide pelo total apenas a coluna quantidade.insritos
# Out:
# 0      21.98
# 1       6.27
# 2       4.05
# 3       2.29
# 4       2.12
#        ...
# 157     0.08
# 158     0.07
# 159     0.07
# 160     0.06
# 161     0.06
# Name: Quantidade_Inscritos, Length: 162, dtype: float64

# %%
#Como slavar dentro do dataframe
#Criou um data demtro
df_quantidade_inscritos['Porcentual_Inscritos'] = (df_quantidade_inscritos.Quantidade_Inscritos/ total* 100).round(2)

# %%
df_quantidade_inscritos['NU_ANO'] = 2021

# %%
df_quantidade_inscritos
# Out:
#                 Município  COD_IBGE  Quantidade_Inscritos  \
# 0                Salvador   2927408                 58502
# 1        Feira de Santana   2910800                 16689
# 2    Vitória da Conquista   2933307                 10792
# 3               Barreiras   2903201                  6083
# 4        Lauro de Freitas   2919207                  5647
# ..                    ...       ...                   ...
# 157              Sento Sé   2930204                   200
# 158             São Félix   2929008                   179
# 159               Itanhém   2916005                   175
# 160     Riachão das Neves   2926202                   172
# 161               Jussara   2918506                   165
#
#      Porcentual_Inscritos  NU_ANO
# 0                   21.98    2021
# 1                    6.27    2021
# 2                    4.05    2021
# 3                    2.29    2021
# 4                    2.12    2021
# ..                    ...     ...
# ...

# %% [markdown]
# # Como juntar os dois dataframes

# %%
df_quantidade_inscritos.head()
# Out:
#               Município  COD_IBGE  Quantidade_Inscritos  Porcentual_Inscritos  \
# 0              Salvador   2927408                 58502                 21.98
# 1      Feira de Santana   2910800                 16689                  6.27
# 2  Vitória da Conquista   2933307                 10792                  4.05
# 3             Barreiras   2903201                  6083                  2.29
# 4      Lauro de Freitas   2919207                  5647                  2.12
#
#    NU_ANO
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021

# %%
df_visao_municipio.head()
# Out:
#               Município  COD_IBGE  Mínimo_MT    Média_MT  Mediana_MT  \
# 0  Vitória da Conquista   2933307      315.5  536.491289      517.30
# 1              Salvador   2927408      315.3  534.623544      515.60
# 2             Barreiras   2903201      318.8  517.589528      496.80
# 3      Feira de Santana   2910800      316.0  525.103365      502.90
# 4              Serrinha   2930501      346.8  501.138564      479.85
#
#    Máximo_MT
# 0      953.1
# 1      953.1
# 2      948.8
# 3      948.5
# 4      948.5

# %% [markdown]
# * Compartilaham o mesmo dado do municipio

# %%
df_municipio = (pd.merge(
    df_visao_municipio,#DATAFRAME DA ESQUERDA, 
    df_quantidade_inscritos, #DATAFRAME DA DIREITA
    on = 'COD_IBGE', #COLUNA QUE OS DOIS COMPARTILHAM
    how = 'inner' #PEGA TUDO QUE TEM INTERCEÇÃO ENTRE OS DATA


)
)

# %%
df_municipio  #municipio duplicado
# Out:
#                 Município_x  COD_IBGE  Mínimo_MT    Média_MT  Mediana_MT  \
# 0      Vitória da Conquista   2933307      315.5  536.491289      517.30
# 1                  Salvador   2927408      315.3  534.623544      515.60
# 2                 Barreiras   2903201      318.8  517.589528      496.80
# 3          Feira de Santana   2910800      316.0  525.103365      502.90
# 4                  Serrinha   2930501      346.8  501.138564      479.85
# ..                      ...       ...        ...         ...         ...
# 157               Cansanção   2906808      360.9  475.027413      459.20
# 158  Oliveira dos Brejinhos   2923209      380.6  505.673239      488.10
# 159                Sento Sé   2930204      367.8  476.352846      462.30
# 160               Umburanas   2932457      357.6  464.582090      453.50
# 161               Caravelas   2906907      352.9  490.168085      480.50
#
#      Máximo_MT             Município_y  Quantidade_Inscritos  \
# ...

# %%
#CORREÇÃO DAS COLUNAS DUPLCIADAS
df_municipio = (pd.merge(
    df_visao_municipio.drop(columns = ['Município']),#DATAFRAME DA ESQUERDA, o drop vai evitar que tenha coluna duplicada
    df_quantidade_inscritos, #DATAFRAME DA DIREITA
    on = 'COD_IBGE', #COLUNA QUE OS DOIS COMPARTILHAM
    how = 'inner' #PEGA TUDO QUE TEM INTERCEÇÃO ENTRE OS DATA


)
)

# %%
df_municipio
# Out:
#      COD_IBGE  Mínimo_MT    Média_MT  Mediana_MT  Máximo_MT  \
# 0     2933307      315.5  536.491289      517.30      953.1
# 1     2927408      315.3  534.623544      515.60      953.1
# 2     2903201      318.8  517.589528      496.80      948.8
# 3     2910800      316.0  525.103365      502.90      948.5
# 4     2930501      346.8  501.138564      479.85      948.5
# ..        ...        ...         ...         ...        ...
# 157   2906808      360.9  475.027413      459.20      726.9
# 158   2923209      380.6  505.673239      488.10      707.2
# 159   2930204      367.8  476.352846      462.30      702.3
# 160   2932457      357.6  464.582090      453.50      686.9
# 161   2906907      352.9  490.168085      480.50      680.2
#
#                   Município  Quantidade_Inscritos  Porcentual_Inscritos  \
# 0      Vitória da Conquista                 10792                  4.05
# 1                  Salvador                 58502                 21.98
# ...

# %% [markdown]
# # HANDS ON

# %%
df_raw = pd.read_csv("C:/Users/marcos perrude/Downloads/poluicao/ENS5173_202401/Aulas/dados_enem_2021_BA/dados_enem_2021_BA.csv")

# %%
import pandas
import numpy as np
import geobr
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 140)
pd.set_option('display.max_rows',140)

import warnings
warnings.filterwarnings('ignore')

# %%
def editar_estado_civil(estado_civil):
    if estado_civil ==0: 
        return 'Não Informado'
    elif estado_civil == 1:
        return 'Solteiro'
    elif estado_civil ==2:
        return 'casado'
    elif estado_civil == 3:
        return 'divorciado'
    else :
        return 'Viuvo'

# %%
df.TP_ESTADO_CIVIL
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 266189    1
# 266190    2
# 266191    0
# 266192    2
# 266193    1
# Name: TP_ESTADO_CIVIL, Length: 266194, dtype: int64

# %%
# ALTERAR DIRETO NA TABELA
df_raw.TP_ESTADO_CIVIL.map({0 : 'Nao Informado', 1 : 'Solteiro', 2 : 'Casado' , 3: 'Divorciado' , 4 : 'Viuvo'})
# Out:
# 0              Solteiro
# 1              Solteiro
# 2              Solteiro
# 3              Solteiro
# 4              Solteiro
#               ...
# 266189         Solteiro
# 266190           Casado
# 266191    Nao Informado
# 266192           Casado
# 266193         Solteiro
# Name: TP_ESTADO_CIVIL, Length: 266194, dtype: object

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210051128744    2021                4       F                1
# 1  210054173438    2021                5       F                1
# 2  210052118573    2021                3       F                1
# 3  210052350230    2021               10       F                1
# 4  210053156861    2021                9       M                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            3                 1                2                0          2
# 1            2                 1                2                0          2
# 2            3                 1                2                0          2
# 3            2                 1                1                8          1
# 4            2                 1                1                5          1
#
#    ...                                 TX_GABARITO_CH  \
# ...
